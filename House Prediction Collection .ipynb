# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset=pd.read_csv('housing.csv')
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
dataset.isnull().sum()
# Out:
# longitude                       0
# latitude                        0
# housing_median_age              0
# total_rooms                     0
# total_bedrooms                207
# population                      0
# households                      0
# median_income                   0
# median_house_value              0
# ocean_proximity_INLAND          0
# ocean_proximity_ISLAND          0
# ocean_proximity_NEAR BAY        0
# ocean_proximity_NEAR OCEAN      0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
dataset.fillna(dataset['total_bedrooms'].median(), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# longitude                     0
# latitude                      0
# housing_median_age            0
# total_rooms                   0
# total_bedrooms                0
# population                    0
# households                    0
# median_income                 0
# median_house_value            0
# ocean_proximity_INLAND        0
# ocean_proximity_ISLAND        0
# ocean_proximity_NEAR BAY      0
# ocean_proximity_NEAR OCEAN    0
# dtype: int64

# %%
import pickle
dataset.to_pickle('House_Preprocessing_data.sav')

# %%
# List of ocean proximity dummy variable columns
#ocean_proximity_columns = ['ocean_proximity_INLAND', 'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN']


# Create 'ocean_proximity' based on the maximum value in the specified columns
#dataset['ocean_proximity'] = dataset[ocean_proximity_columns].idxmax(axis=1)

# Remove the prefix to get clean categor
#dataset['ocean_proximity'] = dataset['ocean_proximity'].str.replace('ocean_proximity_', '')

# Display the updated DataFrame (optional)
#dataset

# %%
#dataa=['ocean_proximity_INLAND','ocean_proximity_ISLAND','ocean_proximity_NEAR BAY','ocean_proximity_NEAR OCEAN']
# Set up the FacetGrid
#g = sns.FacetGrid(dataset, col='median_income', col_wrap=3, height=4)

# Map a scatter plot for each numerical column against price
#for col in dataa:
    #g.map(sns.scatterplot, col, 'median_income')

#plt.show()

# %%
sns.distplot(dataset['households'],kde=True)
# The majority of median incomes fall within a specific range?
# the income is arrange in that area and set middle value income in that arranged income and some of the people living in that area 
#earning below and some of them above  is that correct
#household is the house about to live a family or single person to live in that house
#Population: This refers to the total number of people living in a given area
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4180\3358968400.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['households'],kde=True)
# <Axes: xlabel='households', ylabel='Density'>

# %%
sns.jointplot(x='households',y='total_rooms',hue='median_income',kind='scatter',data=dataset)
# What is the range of total household income in relation to the median value of total rooms shown in the graph

# %%
from sklearn.model_selection import train_test_split
x=dataset.drop('median_house_value',axis=1)
y=dataset.median_house_value
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
from sklearn.feature_selection import SelectKBest,f_regression
from sklearn.feature_selection import chi2
selector=SelectKBest(score_func=f_regression, k=4)
bestk=selector.fit_transform(x_train, y_train)
best=selector.transform(x_test)
best
# Out:
# array([[32.58  ,  4.1518,  0.    ,  0.    ],
#        [33.92  ,  5.7796,  0.    ,  0.    ],
#        [38.65  ,  4.3487,  1.    ,  0.    ],
#        ...,
#        [33.89  ,  7.875 ,  0.    ,  0.    ],
#        [36.56  ,  2.0658,  1.    ,  0.    ],
#        [37.36  ,  4.6761,  0.    ,  0.    ]])

# %%
from sklearn.naive_bayes import GaussianNB
regressor=GaussianNB()
regressor.fit(bestk,y_train)
# Out:
# GaussianNB()

# %%
y_pred=regressor.predict(best)
from sklearn.metrics import r2_score
r2score=r2_score(y_pred,y_test)

# %%
r2score
# Out:
# 0.2890830605876902

# %%
import pickle
file='finale.sav'

# %%
pickle.dump(regressor,open(file,'wb'))
res1=pickle.load(open('finale.sav','rb'))
res2=res1.predict([[42.33,2.3,1,0]])
res2
# Out:
# array([65500.])
